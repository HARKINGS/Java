# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
# Out:
# 2024-05-15 11:29:14.303102: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-15 11:29:14.303211: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-15 11:29:14.444815: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
tokenizer = AutoTokenizer.from_pretrained("dslim/distilbert-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/distilbert-NER")
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/669k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/966 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]

# %%
nlp = pipeline("ner", model=model, tokenizer=tokenizer)
example = "My name is Ngoc and I live in Berlin"

# %%
ner_results = nlp(example)
print(ner_results)
# Out:
# [{'entity': 'LABEL_0', 'score': 0.9994962, 'index': 1, 'word': 'My', 'start': 0, 'end': 2}, {'entity': 'LABEL_0', 'score': 0.99957675, 'index': 2, 'word': 'name', 'start': 3, 'end': 7}, {'entity': 'LABEL_0', 'score': 0.9995974, 'index': 3, 'word': 'is', 'start': 8, 'end': 10}, {'entity': 'LABEL_1', 'score': 0.99823076, 'index': 4, 'word': 'Ng', 'start': 11, 'end': 13}, {'entity': 'LABEL_1', 'score': 0.9973894, 'index': 5, 'word': '##oc', 'start': 13, 'end': 15}, {'entity': 'LABEL_0', 'score': 0.9995989, 'index': 6, 'word': 'and', 'start': 16, 'end': 19}, {'entity': 'LABEL_0', 'score': 0.9946306, 'index': 7, 'word': 'I', 'start': 20, 'end': 21}, {'entity': 'LABEL_0', 'score': 0.99943334, 'index': 8, 'word': 'live', 'start': 22, 'end': 26}, {'entity': 'LABEL_0', 'score': 0.9994185, 'index': 9, 'word': 'in', 'start': 27, 'end': 29}, {'entity': 'LABEL_5', 'score': 0.9974118, 'index': 10, 'word': 'Berlin', 'start': 30, 'end': 36}]

# %% [markdown]
# [
#     {
#         'entity': 'LABEL_0',
#         'score': 0.9992238,
#         'index': 1,
#         'word': 'My',
#         'start': 0,
#         'end': 2
#     },
#
#     {
#         'entity': 'LABEL_0',
#         'score': 0.9994271,
#         'index': 2,
#         'word': 'name',
#         'start': 3,
#         'end': 7
#     },
#
#     {
#         'entity': 'LABEL_0',
#         'score': 0.99953353,
#         'index': 3,
#         'word': 'is',
#         'start': 8,
#         'end': 10
#     },
#
#     {
#         'entity': 'LABEL_1',
#         'score': 0.99110633,
#         'index': 4,
#         'word': 'Wolfgang',
#         'start': 11,
#         'end': 19
#     },
#
#     {
#         'entity': 'LABEL_0',
#         'score': 0.9994848,
#         'index': 5,
#         'word': 'and',
#         'start': 20,
#         'end': 23
#     },
#
#     {
#         'entity': 'LABEL_0',
#         'score': 0.9873789,
#         'index': 6,
#         'word': 'I',
#         'start': 24,
#         'end': 25
#     },
#
#     {
#         'entity': 'LABEL_0',
#         'score': 0.9990946,
#         'index': 7,
#         'word': 'live',
#         'start': 26,
#         'end': 30
#     },
#
#     {
#         'entity': 'LABEL_0',
#         'score': 0.9990859,
#         'index': 8,
#         'word': 'in',
#         'start': 31,
#         'end': 33
#     },
#
#     {
#         'entity': 'LABEL_5',
#         'score': 0.9967968,
#         'index': 9,
#         'word': 'Berlin',
#         'start': 34,
#         'end': 40
#     }
# ]

# %% [markdown]
# [
#     {
#         'entity': 'B-PER',
#         'score': 0.9990139,
#         'index': 4,
#         'word': 'Wolfgang',
#         'start': 11,
#         'end': 19
#     },
#
#     {
#         'entity': 'B-LOC',
#         'score': 0.999645,
#         'index': 9,
#         'word': 'Berlin',
#         'start': 34,
#         'end': 40
#     }
# ]

# %%
# from transformers import AutoTokenizer, AutoModelForTokenClassification
# from transformers import pipeline

# tokenizer = AutoTokenizer.from_pretrained("dslim/distilbert-NER")
# model = AutoModelForTokenClassification.from_pretrained("dslim/distilbert-NER")

# nlp = pipeline("ner", model=model, tokenizer=tokenizer)
# example = "My name is Wolfgang and I live in Berlin"

# ner_results = nlp(example)
# print(ner_results)

# %%
import pickle
filename = 'Ner'
pickle.dump(model, open(filename, 'wb'))
